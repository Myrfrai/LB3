# %%
movies = [
{
"name": "Usual Suspects", 
"imdb": 7.0,
"category": "Thriller"
},
{
"name": "Hitman",
"imdb": 6.3,
"category": "Action"
},
{
"name": "Dark Knight",
"imdb": 9.0,
"category": "Adventure"
},
{
"name": "The Help",
"imdb": 8.0,
"category": "Drama"
},
{
"name": "The Choice",
"imdb": 6.2,
"category": "Romance"
},
{
"name": "Colonia",
"imdb": 7.4,
"category": "Romance"
},
{
"name": "Love",
"imdb": 6.0,
"category": "Romance"
},
{
"name": "Bride Wars",
"imdb": 5.4,
"category": "Romance"
},
{
"name": "AlphaJet",
"imdb": 3.2,
"category": "War"
},
{
"name": "Ringing Crime",
"imdb": 4.0,
"category": "Crime"
},
{
"name": "Joking muck",
"imdb": 7.2,
"category": "Comedy"
},
{
"name": "What is the name",
"imdb": 9.2,
"category": "Suspense"
},
{
"name": "Detective",
"imdb": 7.0,
"category": "Suspense"
},
{
"name": "Exam",
"imdb": 4.2,
"category": "Thriller"
},
{
"name": "We Two",
"imdb": 7.2,
"category": "Romance"
}
]
#1
def single_movie(listoc, movieuser):
    for x in listoc:
        if x['name'] == movieuser:
            return x["imdb"] > 5.5

movieuser = input("Write your movie: ")
print(f'Imbd rating: {single_movie(movies , movieuser)}')

print("\n") #__________________________________________________________________
#2
def sublist(listo):
    bestmovies = []
    for x in listo:
        if x['imdb'] > 5.5:
            niceone = {
                    "name": x["name"], 
                    "imdb": x["imdb"]
                    }
            bestmovies.append(niceone)
    print(bestmovies)        
sublist(movies)

print("\n") #__________________________________________________________________
#3
def category(listo, catuser):
    return [x for x in listo if x['category'] == catuser]

categoryuser = input("Write yout category: ")
youtlist = category(movies, categoryuser)
print(f"Your category: {categoryuser} and the list of movies: ")
for catmovie in youtlist:
    print(catmovie['name'])

print("\n") #__________________________________________________________________
#4
def avgIMDB(mylist, dict):
    avg = 0
    if len(mylist) == 0:
        print("Nothing")
        return 0
    for x in dict:
        for y in mylist:
            if x['name'] == y:
                avg += x['imdb']
    print('The average IMDB:', avg/len(mylist))            

user1 = ['Love', 'Colonia', 'Detective', 'Bride Wars']
user2 = []
user3 = ['Usual Suspects', 'Hitman', 'Dark Knight', 'The Choice', 'AlphaJet', 'What is the name']
avgIMDB(user1, movies) 
avgIMDB(user2, movies)         
avgIMDB(user3, movies)     

print("\n") #__________________________________________________________________
#5 
def catIMDB(cat, dict):
    avg = 0
    count = 0
    for x in dict:
        if x['category'] == cat:
            avg += x['imdb']
            count += 1
    if count == 0:
        print("Nothing")
    else: print(f'Your average IMDB: {avg / count} for categogy: {cat}')            

category = input("Write yout categoty: ")
catIMDB(category, movies)
# Out:
# Imbd rating: True
#
#
# [{'name': 'Usual Suspects', 'imdb': 7.0}, {'name': 'Hitman', 'imdb': 6.3}, {'name': 'Dark Knight', 'imdb': 9.0}, {'name': 'The Help', 'imdb': 8.0}, {'name': 'The Choice', 'imdb': 6.2}, {'name': 'Colonia', 'imdb': 7.4}, {'name': 'Love', 'imdb': 6.0}, {'name': 'Joking muck', 'imdb': 7.2}, {'name': 'What is the name', 'imdb': 9.2}, {'name': 'Detective', 'imdb': 7.0}, {'name': 'We Two', 'imdb': 7.2}]
#
#
# Your category: Romance and the list of movies:
# The Choice
# Colonia
# Love
# Bride Wars
# We Two
#
#
# The average IMDB: 6.45
# Nothing
# The average IMDB: 6.816666666666666
#
#
# Your average IMDB: 8.1 for categogy: Suspense
